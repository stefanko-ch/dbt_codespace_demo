# %% [markdown]
# # Exercise 1: First Steps with DuckDB
#
# **Learning Objectives:**
# - Create a DuckDB connection
# - Create tables with CREATE TABLE
# - Insert data with INSERT
# - Query data with SELECT, WHERE, ORDER BY
# - Use aggregations: COUNT, AVG, GROUP BY
#
# **Estimated Time:** 20-30 minutes

# %% [markdown]
# ## Setup
#
# First, install DuckDB (if not already installed):

# %%
# Idempotent notebook-dep installer (safe to rerun).
# Uses uv from the Codespace; falls back to pip if running standalone.
import importlib.util, subprocess, sys, shutil
_pkgs = {'sql': 'jupysql', 'duckdb': 'duckdb',
         'duckdb_engine': 'duckdb-engine', 'prettytable': 'prettytable'}
_missing = [p for m, p in _pkgs.items() if importlib.util.find_spec(m) is None]
if _missing:
    cmd = (['uv', 'pip', 'install', '--python', sys.executable]
           if shutil.which('uv')
           else [sys.executable, '-m', 'pip', 'install'])
    subprocess.check_call(cmd + _missing)
    print('Installed:', _missing)
else:
    print('All notebook deps already present.')

# %%
import duckdb

# %% [markdown]
# ---
# ## Task 1: Create a Connection
#
# Create an in-memory DuckDB connection and store it in the variable `conn`.
#
# **Syntax:** `duckdb.connect(':memory:')` or `duckdb.connect()`
#
# **Expected Result:** An active connection without error messages

# %%
# Your code here:
conn =

# %% [markdown]
# ---
# ## Task 2: Create a Table and Insert Data
#
# Create a table `students` with the following structure:
#
# | Column | Data Type | Description |
# |--------|-----------|-------------|
# | id | INTEGER | Unique ID |
# | name | VARCHAR | Full name |
# | age | INTEGER | Age in years |
# | major | VARCHAR | Field of study |
#
# Then insert **at least 5 students** with this data:
#
# ```
# 1, 'Anna Miller', 22, 'Computer Science'
# 2, 'Ben Smith', 25, 'Mathematics'
# 3, 'Clara Weber', 21, 'Computer Science'
# 4, 'David Klein', 24, 'Physics'
# 5, 'Eva Fischer', 23, 'Mathematics'
# ```
#
# **Syntax:**
# ```sql
# CREATE TABLE tablename (column1 TYPE, column2 TYPE, ...);
# INSERT INTO tablename VALUES (value1, value2, ...), (value1, value2, ...);
# ```

# %%
# Your code here:

# %% [markdown]
# ---
# ## Task 3: Query Data
#
# ### 3a) Show all students
#
# Write a query that returns **all columns** of all students.
#
# **Expected Result:** A table with 5 rows and 4 columns (id, name, age, major)

# %%
# Your code here:

# %% [markdown]
# ### 3b) Show only names and majors
#
# Write a query that returns **only the columns `name` and `major`**.
#
# **Expected Result:** A table with 5 rows and 2 columns

# %%
# Your code here:

# %% [markdown]
# ### 3c) Find all students over 22 years old
#
# Write a query with a **WHERE condition** that shows only students with `age > 22`.
#
# **Expected Result:** 2-3 students (Ben, David, Eva)

# %%
# Your code here:

# %% [markdown]
# ---
# ## Task 4: Aggregations
#
# ### 4a) How many students are there in total?
#
# Use the **COUNT()** function.
#
# **Expected Result:** A single number (5)

# %%
# Your code here:

# %% [markdown]
# ### 4b) What is the average age?
#
# Use the **AVG()** function on the `age` column.
#
# **Expected Result:** A decimal number (approximately 23.0)

# %%
# Your code here:

# %% [markdown]
# ### 4c) How many students per major?
#
# Use **GROUP BY** together with **COUNT()**.
#
# **Expected Result:**
# | major | count |
# |-------|-------|
# | Computer Science | 2 |
# | Mathematics | 2 |
# | Physics | 1 |

# %%
# Your code here:

# %% [markdown]
# ---
# ## Bonus Task ⭐
#
# Find the **youngest and oldest student** in each major.
#
# **Tips:**
# - Use `MIN(age)` and `MAX(age)`
# - Group by `major`
#
# **Expected Result:**
# | major | youngest | oldest |
# |-------|----------|--------|
# | Computer Science | 21 | 22 |
# | Mathematics | 23 | 25 |
# | Physics | 24 | 24 |

# %%
# Your code here:

# %% [markdown]
# ---
# ## 🎉 Congratulations!
#
# You've completed the first exercise. Continue to Exercise 2!
#
# **What you learned:**
# - ✅ Create a DuckDB connection
# - ✅ Create tables and insert data
# - ✅ SELECT, WHERE, ORDER BY
# - ✅ COUNT, AVG, MIN, MAX
# - ✅ GROUP BY
